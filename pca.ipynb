# %% [markdown]
# <a href="https://colab.research.google.com/github/marghemar/marghe.mar/blob/main/Import_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.decomposition import PCA

# %%
def run_PCA(X):
    pca = PCA(n_components=X.shape[1]-1)
    pcaX = pca.fit_transform(X.iloc[:,:-1].values)
    columnsX =  ['PC'+str(i+1) for i in range(X.shape[1]-1)]
    principal_X = pd.DataFrame(data = pcaX, columns = columnsX, index = X.index )
    print(pca.explained_variance_ratio_)
    print(pca.singular_values_)
    targets = ['Damage','No Damage']
    targets_num = [1,0]
    colors = ['g', 'r']

    fig, axes = plt.subplots(2,2)

    fig.set_size_inches(30, 30)


    for i in range(2):
        for j in range(2):
            for target, color in zip(targets_num,colors):
                indicesToKeep = X['any_damage'] == target
                axes[i,j].scatter(principal_X.loc[indicesToKeep, 'PC'+str(i*2+j+1)], principal_X.loc[indicesToKeep, 'PC'+str(i*2+j+2)], c = color, s = 50)
            axes[i,j].title.set_text('PC '+str(i*2+j+1)+' and ' +str(i*2+j+2))
            axes[i,j].set_xlabel('PC '+str(i*2+j+1))
            axes[i,j].set_ylabel('PC '+str(i*2+j+2))
            axes[i,j].legend(targets,prop={'size': 15})
# Out:
#                     PC1       PC2       PC3       PC4       PC5       PC6  \
# ID Date
# 0  2020-10-15  2.223852 -0.181391 -2.820874 -0.128719  1.024024  2.256422
#    2020-10-11  1.716257 -0.190275 -2.378924 -0.428547  1.506328  1.694262
#    2020-10-10  0.199419 -0.292605 -2.753819 -0.109373  1.026158  2.140724
#    2020-09-07 -1.431208 -0.346874 -1.795298 -0.724247  2.296966  1.146350
#    2020-09-06 -1.377412 -0.349796 -1.811382 -0.645740  1.935121  1.237646
# ...                 ...       ...       ...       ...       ...       ...
# 10 2009-09-14 -1.122725 -4.467129  1.516524  4.046572  1.863737  1.373594
#    2009-09-13 -2.462858 -4.618698  1.953156  4.041693  1.050741  1.740318
#    2009-09-03 -3.220558 -4.582353  2.012379  3.752777  2.511257  0.745526
#    2009-09-02 -3.119602 -4.529143  1.510242  4.078167  1.869624  1.356262
#    2009-08-29  2.966652 -5.661355  4.454902  5.268567 -6.343175  6.605772
#
# ...

# %%
#figPCA.title("Principal Component Analysis",fontsize=20)
