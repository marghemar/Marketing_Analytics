# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import metrics
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestRegressor

from sklearn.neural_network import MLPRegressor

from sklearn.inspection import permutation_importance
import IPython

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# set up to view all the info of the columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# **Input Data**
# * Data stored in a csv file are stored in a dataframe

# %%
cars_original = pd.read_csv(r'C:\Users\margh\OneDrive\Documenti\GIT\Marketing_Analytics\car_data.csv')
cars_original.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %% [markdown]
# ### **Exploratory Data Analysis**
# * The analysis report presents that the DataFrame has 11914 rows and each row represents one car. The DataFrame has 16 features, 8 of which are catergorical. Engine Fuel Type, Engine HP, Engine Cylinders, Number of Doors, Market Category present missing values.

# %%
#@ Exploratory Data Analysis:
cars_original.info()                  # Inspecting the DataFrame.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.5+ MB

# %%
#@ Inspecting the Data using Histograms:
# %matplotlib inline
import matplotlib.pyplot as plt
cars_original.hist(bins=50, figsize=(20, 15))   
plt.show()

# %% [markdown]
# ### **Clean the database**
# * The database presents missing values, probably wrong values and cathegorical variables. The first two categories will be fixed while the third will be transformed in numberical by one hot encoding

# %% [markdown]
# ### **Number of Doors**
# * There is clearly a different definition for the number of doors, so I changed 3 to 2 for coherence

# %%
cars = cars_original.copy()
cars[cars['Number of Doors'] == 3]['Number of Doors']=2

# %% [markdown]
# ### **Outliers**
# * I checked the outliers. The value of highway MPG>300 is a mistype so I removed it ( I could have fixed but I did not see the point)

# %%
# See if there is any outliers

# select columns to plot

cars['logMSRP']= np.log(cars.MSRP)
# subplots
cars.plot(subplots=True, layout=(5,4), kind='box', figsize=(12,14), patch_artist=True)
plt.suptitle('Find Outliers', fontsize=15, y=0.9)
plt.savefig('boxplots.png', bbox_inches='tight')

cars = cars[cars['highway MPG']<200]

# %% [markdown]
# ### **Fill Nan**
# * Engine Fuel Type: only 3 are missing, so I fill with the average value of the same make and model, which is constant
# * Missing vlues for electric cars are averaged over electric cars only
# * Flex fuel with gas is the average of the same MAKE/MODEL/YEAR

# %%
fill_mode = lambda g:g.fillna(g.value_counts().idxmax()[0])
cars[['Engine Fuel Type']] = cars[['Engine Fuel Type']].groupby([cars['Make'],cars['Model']]).apply(fill_mode)

fill_mean = lambda g: g.fillna(round(g.mean()))
cars[['Engine HP','Engine Cylinders','highway MPG','city mpg' ]] = cars[['Engine HP','Engine Cylinders','highway MPG','city mpg']].groupby([cars['Make'],cars['Model'],cars['Year'],cars['Engine Fuel Type']]).apply(fill_mean)
cars[['Engine HP','Engine Cylinders','highway MPG','city mpg' ]] = cars[['Engine HP','Engine Cylinders','highway MPG','city mpg']].groupby([cars['Make'],cars['Model'],cars['Engine Fuel Type']]).apply(fill_mean)
cars[['Engine HP','Engine Cylinders','highway MPG','city mpg' ]] = cars[['Engine HP','Engine Cylinders','highway MPG','city mpg']].groupby([cars['Engine Fuel Type']]).apply(fill_mean)
cars[['Engine HP','Engine Cylinders','highway MPG','city mpg' ]] = cars[['Engine HP','Engine Cylinders','highway MPG','city mpg']].groupby([cars['Make'],cars['Model'],cars['Year']]).apply(fill_mean)
cars[['Number of Doors' ]] = cars[['Number of Doors']].groupby([cars['Make'],cars['Model'],cars['Year']]).apply(fill_mean)
cars[['Number of Doors' ]] = cars[['Number of Doors']].groupby([cars['Make'],cars['Model']]).apply(fill_mean)

cars.info()

# %% [markdown]
# ### **Year**
# * There is a major change at year 2000 in prices.
# I test also separate analysis for the two sectors

# %%
fig, ax = plt.subplots(1,1)

ax.scatter(cars.Year, cars.MSRP, c='red')

ax.set_xlabel('year')
ax.set_ylabel('price')
ax.set_xlim([1990, 2022])
ax.set_ylim([0, 30000])
# Out:
# (0.0, 30000.0)

# %% [markdown]
# ### **Extra Variables**
# * I will add the variable log of the price, that seems promsing as target variable because it will balance the influence of low price cars in the loss function

# %%
makes =set(cars['Make'])
models = set(cars['Model'])


y = cars[['MSRP']]
ys = cars[['MSRP','logMSRP']]
X = cars.drop(columns=['MSRP','logMSRP'])

# %% [markdown]
# ### **Split**
# * Random split between test / val / train. We split randomly each make as we want in the training / val/test elements of each make

# %%
for i,make in enumerate(makes):
    X_tmp = X[cars.Make == make]
    y_tmp = ys[cars.Make == make]

    X_train_tmp, X_test_tmp, y_train_tmp, y_test_tmp = train_test_split(X_tmp,y_tmp, test_size=0.2, random_state=1)
    X_train_tmp, X_val_tmp, y_train_tmp, y_val_tmp = train_test_split(X_train_tmp, y_train_tmp, test_size=0.25, random_state=1)
    if i==0:
        X_train = X_train_tmp
        X_test = X_test_tmp
        X_val = X_val_tmp
    else:
        X_train = pd.concat([X_train, X_train_tmp], axis=0)
        X_test = pd.concat([X_test, X_test_tmp], axis=0)
        X_val = pd.concat([X_val, X_val_tmp], axis=0)

    if i==0:
        ys_train = y_train_tmp
        ys_test = y_test_tmp
        ys_val = y_val_tmp
    else:
        ys_train = pd.concat([ys_train, y_train_tmp], axis=0)
        ys_test = pd.concat([ys_test, y_test_tmp], axis=0)
        ys_val = pd.concat([ys_val, y_val_tmp], axis=0)

# %% [markdown]
# ### **Support functions**
# * prepare_data: it creates data structure with one hot encoding. If the analysis is performed make by make, The columns of one hot encoding are the merge of the columns needed in test, train and val set for that make.
# * plot_result_1: comparison on expected and predicted results

# %% [markdown]
# **Market category**
# * This column includes a list of elements
# * it is transformed in several columns, one for each element

# %%
def create_one_hot(X,make=''):
    if make!='':
        X=X.drop(columns=['Make'])
    mc = X['Market Category'].str.get_dummies(',')
    c_0 =X.drop('Market Category', axis = 1)
    X = pd.concat([c_0, mc], axis=1)
    X=pd.get_dummies(X)
    return X


def prepare_data(make,X_train,X_val,X_test,y_train,y_val,y_test):
    if make == '':
        
        X_train_tmp =  create_one_hot(X_train)
        X_val_tmp =   create_one_hot(X_val)
        X_test_tmp =   create_one_hot(X_test)
        y_train_tmp = y_train
        y_val_tmp = y_val
        y_test_tmp = y_test

    else:

        X_train_tmp =  create_one_hot(X_train[X_train.Make == make],make)
        X_val_tmp =   create_one_hot(X_val[X_val.Make == make],make)
        X_test_tmp =   create_one_hot(X_test[X_test.Make == make],make)
        y_train_tmp = y_train[X_train.Make == make]
        y_val_tmp = y_val[X_val.Make == make]
        y_test_tmp = y_test[X_test.Make == make]

    train_col=X_train_tmp.columns
    val_col=X_val_tmp.columns
    test_col=X_test_tmp.columns

    cols = list(set(np.concatenate((train_col,test_col,val_col))))
    
    for col in cols:
        if (not (col in X_train_tmp.columns)):
            X_train_tmp[col] = 0
        if (not (col in X_val_tmp.columns)):
            X_val_tmp[col] = 0
        if (not (col in X_test_tmp.columns)):
            X_test_tmp[col] = 0


    X_train_tmp =  X_train_tmp[cols]
    X_val_tmp =  X_val_tmp[cols]
    X_test_tmp =  X_test_tmp[cols]
    return [ X_train_tmp,X_val_tmp,X_test_tmp,np.ravel (y_train_tmp),np.ravel (y_val_tmp),np.ravel (y_test_tmp)]

# %% [markdown]
# ### **Metrics**
# * This is my chioice. I aim to obtain the best mean_absolute_percentage_error, while the loss function used in the random forest is the RMSE target value (I test the price as the log of the price as target variables)

# %%
def plot_result_1(y_val, y_val_pred,ylog = False,title= 'validation'):
    if ylog:
        y_val = np.exp(y_val)
        y_val_pred = np.exp(y_val_pred)
    error = metrics.mean_absolute_percentage_error(y_val, y_val_pred, )
    print(' Mean Absolute percentage Error:', error )


    fig, axes = plt.subplots(1,3)
    fig.set_size_inches(14, 3)
    fig.tight_layout()
    fig.subplots_adjust(left=0.1,  bottom=0.1, right=0.9, top=0.9, wspace=0.4, hspace=0.4)

    ax= axes[0]
    ax.scatter(np.ravel (y_val), np.ravel (y_val_pred), c='red')
    ax.plot(np.ravel (y_val), np.ravel (y_val), c='blue')
    ax.set_xlabel('Real value')
    ax.set_ylabel('Predicted value')


    ax= axes[1]
    ax.scatter(np.ravel (y_val), np.ravel (y_val_pred), c='red')
    ax.plot(np.ravel (y_val), np.ravel (y_val), c='blue')
    ax.set_title(title+' - recorded vs predicted ')
    ax.set_xlabel('Real value')
    ax.set_ylabel('Predicted value')
    ax.set_xlim([0, 500000])
    ax.set_ylim([0, 500000])
    


    ax= axes[2]
    ax.scatter(np.ravel (y_val), np.ravel (y_val_pred), c='red')
    ax.plot(np.ravel (y_val), np.ravel (y_val), c='blue')
    ax.set_xlabel('Real value')
    ax.set_ylabel('Predicted value')
    ax.set_xlim([0, 50000])
    ax.set_ylim([0, 50000])
    plt.show() 
    return error

# %% [markdown]
# ### **Tuning**
# * Several hyperparameter options and several algorithms are tested
# * Most algorithms perform in a similar way on the validation test. I then opted for the simpler model with the same quality
# * Log analysis slightly outperforms the non log one, no major differences
# * whole analysis slightly outperforms the analysis make by make and period, however it is much more efficient

# %% [markdown]
# **Target = log of price, all makes**
# * Several Random Forest and MLP algorithms are tested

# %%
ylog = True
if ylog:
    y_train = ys_train[['logMSRP']]
    y_val = ys_val[['logMSRP']]
    y_test = ys_test[['logMSRP']]
else:
    y_train = ys_train[['MSRP']]
    y_val = ys_val[['MSRP']]
    y_test = ys_test[['MSRP']]

# %%
rg_list = []
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=10, n_jobs=-1))
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=20, n_jobs=-1))
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=50, n_jobs=-1))
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=100, n_jobs=-1))

names = ['RF 10','RF 20','RF 50','RF 100']


for j ,rg in enumerate (rg_list):
    
    [ X_train_tmp,X_val_tmp,X_test_tmp,y_train_tmp,y_val_tmp,y_test_tmp] = prepare_data( make='',X_train=X_train,X_val=X_val,X_test=X_test,y_train=y_train,y_val=y_val,y_test=y_test)
    rg.fit(X_train_tmp, y_train_tmp)
    y_val_pred=rg.predict(X_val_tmp)
    y_train_pred=rg.predict(X_train_tmp)
    y_test_pred=rg.predict(X_test_tmp)

            
    error =plot_result_1(y_val, y_val_pred,title = names[j]+ ' - Validation - log test',ylog = ylog)
    error =plot_result_1(y_train, y_train_pred,title = names[j]+ ' - Training - log test',ylog = ylog)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\margh\Anaconda3\envs\python_env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Model_SC 300'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\margh\Anaconda3\envs\python_env\lib\site-packages\pandas\core\frame.py in _set_item_mgr(self, key, value)
#    3798         try:
# -> 3799             loc = self._info_axis.get_loc(key)
#    3800         except KeyError:
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#
# KeyError: 'Model_SC 300'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18588/1799622035.py in <module>
#      10 for j ,rg in enumerate (rg_list):
#      11
# ---> 12     [ X_train_tmp,X_val_tmp,X_test_tmp,y_train_tmp,y_val_tmp,y_test_tmp] = prepare_data( make='',X_train=X_train,X_val=X_val,X_test=X_test,y_train=y_train,y_val=y_val,y_test=y_test)
#      13     rg.fit(X_train_tmp, y_train_tmp)
#      14     y_val_pred=rg.predict(X_val_tmp)
#
# ~\AppData\Local\Temp/ipykernel_18588/782410800.py in prepare_data(make, X_train, X_val, X_test, y_train, y_val, y_test)
#      38             X_train_tmp[col] = 0
#      39         if (not (col in X_val_tmp.columns)):
# ---> 40             X_val_tmp[col] = 0
#      41         if (not (col in X_test_tmp.columns)):
#      42             X_test_tmp[col] = 0
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3653         else:
#    3654             # set column
# -> 3655             self._set_item(key, value)
#    3656
#    3657     def _setitem_slice(self, key: slice, value):
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3843                     value = np.tile(value, (len(existing_piece.columns), 1)).T
#    3844
# -> 3845         self._set_item_mgr(key, value)
#    3846
#    3847     def _set_value(
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\site-packages\pandas\core\frame.py in _set_item_mgr(self, key, value)
#    3800         except KeyError:
#    3801             # This item wasn't present, just insert at end
# -> 3802             self._mgr.insert(len(self._info_axis), key, value)
#    3803         else:
#    3804             self._iset_item_mgr(loc, value)
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value)
#    1262                 "instead. To get a de-fragmented frame, use `newframe = frame.copy()`",
#    1263                 PerformanceWarning,
# -> 1264                 stacklevel=find_stack_level(),
#    1265             )
#    1266
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\site-packages\pandas\util\_exceptions.py in find_stack_level()
#      30     (tests notwithstanding).
#      31     """
# ---> 32     stack = inspect.stack()
#      33
#      34     import pandas as pd
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\inspect.py in stack(context)
#    1524 def stack(context=1):
#    1525     """Return a list of records for the stack above the caller's frame."""
# -> 1526     return getouterframes(sys._getframe(1), context)
#    1527
#    1528 def trace(context=1):
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\inspect.py in getouterframes(frame, context)
#    1501     framelist = []
#    1502     while frame:
# -> 1503         frameinfo = (frame,) + getframeinfo(frame, context)
#    1504         framelist.append(FrameInfo(*frameinfo))
#    1505         frame = frame.f_back
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\inspect.py in getframeinfo(frame, context)
#    1475         start = lineno - 1 - context//2
#    1476         try:
# -> 1477             lines, lnum = findsource(frame)
#    1478         except OSError:
#    1479             lines = index = None
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\inspect.py in findsource(object)
#     790             raise OSError('source code not available')
#     791
# --> 792     module = getmodule(object, file)
#     793     if module:
#     794         lines = linecache.getlines(file, module.__dict__)
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\inspect.py in getmodule(object, _filename)
#     743     # Copy sys.modules in order to cope with changes while iterating
#     744     for modname, module in sys.modules.copy().items():
# --> 745         if ismodule(module) and hasattr(module, '__file__'):
#     746             f = module.__file__
#     747             if f == _filesbymodname.get(modname, None):
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\site-packages\IPython\utils\shimmodule.py in __getattr__(self, key)
#      90         name = "%s.%s" % (self._mirror, key)
#      91         try:
# ---> 92             return import_item(name)
#      93         except ImportError:
#      94             raise AttributeError(key)
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\site-packages\IPython\utils\importstring.py in import_item(name)
#      29         # called with 'foo.bar....'
#      30         package, obj = parts
# ---> 31         module = __import__(package, fromlist=[obj])
#      32         try:
#      33             pak = getattr(module, obj)
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\importlib\_bootstrap.py in _find_spec(name, path, target)
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\importlib\_bootstrap_external.py in find_spec(cls, fullname, path, target)
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\importlib\_bootstrap_external.py in _get_spec(cls, fullname, path, target)
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\importlib\_bootstrap_external.py in find_spec(self, fullname, target)
#
# c:\Users\margh\Anaconda3\envs\python_env\lib\importlib\_bootstrap_external.py in _path_stat(path)
#
# KeyboardInterrupt:

# %% [markdown]
# **Target = log of price, subset of features**
# * according to the feature importance, only the first 3 features
# * all features except make and model which strongly increase the computational cost

# %%
rg= RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=20, n_jobs=-1)

       # X=X.drop(columns=['Make'])
[ X_train_tmp,X_val_tmp,X_test_tmp,y_train_tmp,y_val_tmp,y_test_tmp] = prepare_data( 
    make='',X_train=X_train[['Year','Engine HP', 'Market Category']],X_val=X_val[['Year','Engine HP', 'Market Category']],
    X_test=X_test[['Year','Engine HP', 'Market Category']],y_train=y_train,y_val=y_val,y_test=y_test)
rg.fit(X_train_tmp, y_train_tmp)
y_val_pred=rg.predict(X_val_tmp)
y_train_pred=rg.predict(X_train_tmp)
y_test_pred=rg.predict(X_test_tmp)

        
error =plot_result_1(y_val, y_val_pred,title =  '3 Feature - Validation - log test',ylog = ylog)
error =plot_result_1(y_train, y_train_pred,title = 3' Feature - Training - log test',ylog = ylog)

# %%
rg= RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=20, n_jobs=-1)

[ X_train_tmp,X_val_tmp,X_test_tmp,y_train_tmp,y_val_tmp,y_test_tmp] = prepare_data( 
    make='',X_train=X_train.drop(columns=['Make', 'Model']),X_val=X_val.drop(columns=['Make', 'Model']),
    X_test=X_test.drop(columns=['Make', 'Model']),y_train=y_train,y_val=y_val,y_test=y_test)
rg.fit(X_train_tmp, y_train_tmp)
y_val_pred=rg.predict(X_val_tmp)
y_train_pred=rg.predict(X_train_tmp)
y_test_pred=rg.predict(X_test_tmp)

        
error =plot_result_1(y_val, y_val_pred,title = 'No Make and Model - Validation - log test',ylog = ylog)
error =plot_result_1(y_train, y_train_pred,title = 'No Make and Model - Training - log test',ylog = ylog)

# %% [markdown]
# **Target = log of price, make by make**
# * Several Random Forest and MLP algorithms are tested
# * Similar results with simpler models as the input features are less ( could be extended to models)

# %%
rg_list = []
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=5, n_jobs=-1))
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=10, n_jobs=-1))
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=20, n_jobs=-1))
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=50, n_jobs=-1))


names = ['RF 5','RF 10','RF 20','RF 50']

year=2000
for j ,rg in enumerate (rg_list):
        
    y_test_pred = pd.Series([])    
    y_val_pred = pd.Series([])         
    y_train_pred = pd.Series([])  
        
    y_test_obs = pd.Series([])    
    y_val_obs = pd.Series([])         
    y_train_obs = pd.Series([])  
        
    for i,make in enumerate(makes):

        [ X_train_tmp,X_val_tmp,X_test_tmp,y_train_tmp,y_val_tmp,y_test_tmp] = prepare_data(  make=make,
        X_train=X_train[X_train.Year<=year],X_val=X_val[X_val.Year<=year],X_test=X_test[X_test.Year<=year],
        y_train=y_train[X_train.Year<=year],y_val=y_val[X_val.Year<=year],y_test=y_test[X_test.Year<=year])
        if (X_train_tmp.shape[0]>0 and X_val_tmp.shape[0]>0 and X_test_tmp.shape[0]>0):
            rg.fit(X_train_tmp, y_train_tmp)
            y_val_pred_tmp=rg.predict(X_val_tmp)
            y_train_pred_tmp=rg.predict(X_train_tmp)
            y_test_pred_tmp=rg.predict(X_test_tmp)

            y_test_pred = np.concatenate((y_test_pred, y_test_pred_tmp))
            y_val_pred = np.concatenate((y_val_pred, y_val_pred_tmp))
            y_train_pred = np.concatenate((y_train_pred, y_train_pred_tmp))
            y_test_obs = np.concatenate((y_test_obs, y_test_tmp))
            y_val_obs = np.concatenate((y_val_obs, y_val_tmp))
            y_train_obs = np.concatenate((y_train_obs, y_train_tmp))

        [ X_train_tmp,X_val_tmp,X_test_tmp,y_train_tmp,y_val_tmp,y_test_tmp] = prepare_data(  make=make,
        X_train=X_train[X_train.Year>year],X_val=X_val[X_val.Year>year],X_test=X_test[X_test.Year>year],
        y_train=y_train[X_train.Year>year],y_val=y_val[X_val.Year>year],y_test=y_test[X_test.Year>year])
        if (X_train_tmp.shape[0]>0 and X_val_tmp.shape[0]>0 and X_test_tmp.shape[0]>0):
            rg.fit(X_train_tmp, y_train_tmp)
            y_val_pred_tmp=rg.predict(X_val_tmp)
            y_train_pred_tmp=rg.predict(X_train_tmp)
            y_test_pred_tmp=rg.predict(X_test_tmp)

            y_test_pred = np.concatenate((y_test_pred, y_test_pred_tmp))
            y_val_pred = np.concatenate((y_val_pred, y_val_pred_tmp))
            y_train_pred = np.concatenate((y_train_pred, y_train_pred_tmp))
            y_test_obs = np.concatenate((y_test_obs, y_test_tmp))
            y_val_obs = np.concatenate((y_val_obs, y_val_tmp))
            y_train_obs = np.concatenate((y_train_obs, y_train_tmp))
 
    error =plot_result_1(y_val_obs, y_val_pred,title = names[j]+ ' - Validation - log test - by make',ylog = ylog)
    error =plot_result_1(y_train_obs, y_train_pred,title = names[j]+ ' - Training - log test - by make',ylog = ylog)

# %% [markdown]
# **Target = price, all makes**
# * Several Random Forest and MLP algorithms are tested

# %%
ylog = False
if ylog:
    y_train = ys_train[['logMSRP']]
    y_val = ys_val[['logMSRP']]
    y_test = ys_test[['logMSRP']]
else:
    y_train = ys_train[['MSRP']]   
    y_val = ys_val[['MSRP']]
    y_test = ys_test[['MSRP']]

# %%
rg_list = []
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=10, n_jobs=-1))
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=20, n_jobs=-1))
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=50, n_jobs=-1))
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=100, n_jobs=-1))

names = ['RF 10','RF 20','RF 50','RF 100']


for j ,rg in enumerate (rg_list):
    
    [ X_train_tmp,X_val_tmp,X_test_tmp,y_train_tmp,y_val_tmp,y_test_tmp] = prepare_data( make='',X_train=X_train,X_val=X_val,X_test=X_test,y_train=y_train,y_val=y_val,y_test=y_test)
    rg.fit(X_train_tmp, y_train_tmp)
    y_val_pred=rg.predict(X_val_tmp)
    y_train_pred=rg.predict(X_train_tmp)
    y_test_pred=rg.predict(X_test_tmp)

            
    error =plot_result_1(y_val, y_val_pred,title = names[j]+ ' - Validation - price test',ylog = ylog)
    error =plot_result_1(y_train, y_train_pred,title = names[j]+ ' - Training - price test',ylog = ylog)

# %%
rg_list = []
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=5, n_jobs=-1))
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=10, n_jobs=-1))
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=20, n_jobs=-1))
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=50, n_jobs=-1))

names = ['RF 5','RF 10','RF 20','RF 50']

year=2000
for j ,rg in enumerate (rg_list):
        
    y_test_pred = pd.Series([])    
    y_val_pred = pd.Series([])         
    y_train_pred = pd.Series([])  
        
    y_test_obs = pd.Series([])    
    y_val_obs = pd.Series([])         
    y_train_obs = pd.Series([])  
        
    for i,make in enumerate(makes):

        [ X_train_tmp,X_val_tmp,X_test_tmp,y_train_tmp,y_val_tmp,y_test_tmp] = prepare_data(  make=make,
        X_train=X_train[X_train.Year<=year],X_val=X_val[X_val.Year<=year],X_test=X_test[X_test.Year<=year],
        y_train=y_train[X_train.Year<=year],y_val=y_val[X_val.Year<=year],y_test=y_test[X_test.Year<=year])
        if (X_train_tmp.shape[0]>0 and X_val_tmp.shape[0]>0 and X_test_tmp.shape[0]>0):
            rg.fit(X_train_tmp, y_train_tmp)
            y_val_pred_tmp=rg.predict(X_val_tmp)
            y_train_pred_tmp=rg.predict(X_train_tmp)
            y_test_pred_tmp=rg.predict(X_test_tmp)

            y_test_pred = np.concatenate((y_test_pred, y_test_pred_tmp))
            y_val_pred = np.concatenate((y_val_pred, y_val_pred_tmp))
            y_train_pred = np.concatenate((y_train_pred, y_train_pred_tmp))
            y_test_obs = np.concatenate((y_test_obs, y_test_tmp))
            y_val_obs = np.concatenate((y_val_obs, y_val_tmp))
            y_train_obs = np.concatenate((y_train_obs, y_train_tmp))

        [ X_train_tmp,X_val_tmp,X_test_tmp,y_train_tmp,y_val_tmp,y_test_tmp] = prepare_data(  make=make,
        X_train=X_train[X_train.Year>year],X_val=X_val[X_val.Year>year],X_test=X_test[X_test.Year>year],
        y_train=y_train[X_train.Year>year],y_val=y_val[X_val.Year>year],y_test=y_test[X_test.Year>year])
        if (X_train_tmp.shape[0]>0 and X_val_tmp.shape[0]>0 and X_test_tmp.shape[0]>0):
            rg.fit(X_train_tmp, y_train_tmp)
            y_val_pred_tmp=rg.predict(X_val_tmp)
            y_train_pred_tmp=rg.predict(X_train_tmp)
            y_test_pred_tmp=rg.predict(X_test_tmp)

            y_test_pred = np.concatenate((y_test_pred, y_test_pred_tmp))
            y_val_pred = np.concatenate((y_val_pred, y_val_pred_tmp))
            y_train_pred = np.concatenate((y_train_pred, y_train_pred_tmp))
            y_test_obs = np.concatenate((y_test_obs, y_test_tmp))
            y_val_obs = np.concatenate((y_val_obs, y_val_tmp))
            y_train_obs = np.concatenate((y_train_obs, y_train_tmp))
 
    error =plot_result_1(y_val_obs, y_val_pred,title = names[j]+ ' - Validation - price - by make',ylog = ylog)
    error =plot_result_1(y_train_obs, y_train_pred,title = names[j]+ ' - Training - price - by make',ylog = ylog)

# %% [markdown]
# ### **Feature importance**
# * Several hyperparameter options and several algorithms are tested
# * Most algorithms perform in a similar way on the validation test. I then opted for the simpler model with the same quality

# %%
ylog = True
if ylog:
    y_train = ys_train[['logMSRP']]
    y_val = ys_val[['logMSRP']]
    y_test = ys_test[['logMSRP']]
else:
    y_train = ys_train[['MSRP']]
    y_val = ys_val[['MSRP']]
    y_test = ys_test[['MSRP']]

# %%
niter=10
rg= RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=20, n_jobs=-1)

[ X_train_tmp,X_val_tmp,X_test_tmp,y_train_tmp,y_val_tmp,y_test_tmp] = prepare_data( make='',X_train=X_train,X_val=X_val,X_test=X_test,y_train=y_train,y_val=y_val,y_test=y_test)
rg.fit(X_train_tmp, y_train_tmp)
ind=[i for i in X_val.columns].append('Best Result')
perm = pd.DataFrame(columns=['AVG_Importance'], index=ind)
y_val_pred=rg.predict(X_val_tmp)
print('y_val_tmp',y_val_tmp)
print('y_val_pred',y_val_pred)   
if ylog:
    y_val_tmp = np.exp(y_val_tmp)
    y_val_pred = np.exp(y_val_pred)


print('y_val_tmp',y_val_tmp)
print('y_val_pred',y_val_pred)       

error = metrics.mean_absolute_percentage_error(y_val_tmp, y_val_pred )

perm.loc['BestResult','AVG_Importance']=error
print(error)
# Out:
# y_val_tmp [12.55637734 12.56016025 11.78447816 ... 10.65855264  7.60090246
#   8.15046791]
# y_val_pred [12.55959382 12.51891769 11.82952662 ... 10.60259956  7.60114198
#   8.11742084]
# y_val_tmp [283900. 284976. 131200. ...  42555.   2000.   3465.]
# y_val_pred [284814.62748242 273461.9292616  137245.50606495 ...  40239.30624795
#    2000.47910011   3352.36328851]
# 0.07187393304743972

# %%
for i,column in enumerate(X_val.columns):
    error_average=0
    print(column)
    for iter in range(niter):
        X_val1 = X_val.copy()
        X_val_shuffled = X_val1.apply(np.random.permutation, axis=0) 
        X_val1[column] =       X_val_shuffled[column]
        X_val_tmp =  create_one_hot(X_val1) 
    
        for col in X_train_tmp.columns:
            if (not (col in X_val_tmp.columns)):
                X_val_tmp[col] = 0
            
        X_val_tmp =  X_val_tmp[X_train_tmp.columns]
    
        y_val_pred_tmp=rg.predict(X_val_tmp)
                
        if ylog:
            y_val_pred_tmp = np.exp(y_val_pred_tmp)

        error = metrics.mean_absolute_percentage_error(y_val_tmp, y_val_pred_tmp )
        
        error_average += error/niter
    print('error_average',error_average)
    perm.loc[column,'AVG_Importance']=error_average
# Out:
# Make
# error_average 0.0805944182809792
# Model
# error_average 0.07840805850250374
# Year
# error_average 1.2930584300293426
# Engine Fuel Type
# error_average 0.08509328034142888
# Engine HP
# error_average 0.4010847800578967
# Engine Cylinders
# error_average 0.07584371977298071
# Transmission Type
# error_average 0.0786998227865808
# Driven_Wheels
# error_average 0.07632659161371966
# Number of Doors
# error_average 0.07342255924462691
# Market Category
# error_average 0.17890170370650738
# Vehicle Size
# error_average 0.08605400626851159
# Vehicle Style
# error_average 0.08569698449923695
# highway MPG
# error_average 0.07730752306257643
# city mpg
# error_average 0.07489442109152916
# Popularity
# error_average 0.07946998813365896

# %%
sort_perm = perm.sort_values(by=['AVG_Importance'])
plt.barh(sort_perm.index, sort_perm['AVG_Importance'])
# Out:
# <BarContainer object of 16 artists>

# %% [markdown]
# ### **Learning curve**
# * The learning curve allows us to check potential pitfalls in the learning process
# * The plot of the error versus complexity (depth of RF in our case) allows to identify overfitting

# %%
fig, axes = plt.subplots(1,1)
fig.set_size_inches(30,10)
fig.tight_layout(pad=10, w_pad=10, h_pad=10.0)


n_range = np.linspace(0.5,100,20)#[d**2 for d in range(1,11, 0.5)]
x_range =np.int32(n_range * np.int32(X_train.shape[0]/100))

error_val=np.zeros(len(n_range))
error_train=np.zeros(len(n_range))
for i_n,n in enumerate(x_range) :  
    X_train_n = X_train.iloc[:n, :]
    y_train_n = y_train.iloc[:n, :]
    [ X_train_tmp,X_val_tmp,X_test_tmp,y_train_tmp,y_val_tmp,y_test_tmp] = prepare_data( make='',X_train=X_train_n,X_val=X_val,X_test=X_test,y_train=y_train_n,y_val=y_val,y_test=y_test)
    rg.fit(X_train_tmp, y_train_tmp)
    y_val_pred=rg.predict(X_val_tmp)
    y_train_pred=rg.predict(X_train_tmp)
    y_test_pred=rg.predict(X_test_tmp)
    error_val[i_n] = metrics.mean_squared_error(np.exp(y_val_tmp), np.exp(y_val_pred), squared = False)
    error_train[i_n] =metrics.mean_squared_error(np.exp(y_train_tmp), np.exp(y_train_pred), squared = False)

        
axes.plot(n_range, error_val, label = 'Validation ')
axes.plot(n_range, error_train, label = 'Train ')
axes.set_ylim(top=100000)

axes.set_title('Learning curve ')
axes.set_ylabel('RMSE',fontsize = 20)
axes.set_xlabel('Data percentage (%)',fontsize = 20)
axes.tick_params(axis='both', which='major', labelsize=16)
# Out:
# error_val [123684.96424309  38358.67861219  26591.40562156  22936.97740485
#   20955.23440216]
# error_train [ 8526.3247251  16738.5153184  16447.89387581 12458.669484
#  12076.98693986]

# %%
rg_list = []
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=5, n_jobs=-1))
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=10, n_jobs=-1))
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=20, n_jobs=-1))
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=50, n_jobs=-1))
rg_list.append( RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=100, n_jobs=-1))

fig, axes = plt.subplots(1,1)
fig.set_size_inches(30,10)
fig.tight_layout(pad=10, w_pad=10, h_pad=10.0)

error_val=np.zeros(len(rg_list))
error_train=np.zeros(len(rg_list))
for j ,rg in enumerate (rg_list):
    n_range = np.linspace(10,100,10)#[d**2 for d in range(1,11, 0.5)]
    x_range =np.int32(n_range * X_train.shape[0]/100)
    
    [ X_train_tmp,X_val_tmp,X_test_tmp,y_train_tmp,y_val_tmp,y_test_tmp] = prepare_data( make='',X_train=X_train,X_val=X_val,X_test=X_test,y_train=y_train,y_val=y_val,y_test=y_test)
    rg.fit(X_train_tmp, y_train_tmp)
    y_val_pred=rg.predict(X_val_tmp)
    y_train_pred=rg.predict(X_train_tmp)
    y_test_pred=rg.predict(X_test_tmp)
    error_val[j] = metrics.mean_squared_error(np.exp(y_val_tmp), np.exp(y_val_pred), squared = False)
    error_train[j] =metrics.mean_squared_error(np.exp(y_train_tmp), np.exp(y_train_pred), squared = False)


            
axes.plot([5,10,20,50,100], error_val, label = 'Validation ')
axes.plot([5,10,20,50,100], error_train, label = 'Train ')
axes.set_ylim(top=100000)

axes.set_title('RMSE versus Depth of the RF ')
axes.set_ylabel('RMSE',fontsize = 20)
axes.set_xlabel('Depth',fontsize = 20)
axes.tick_params(axis='both', which='major', labelsize=16)

# %%
rg= RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=20, n_jobs=-1)

[ X_train_tmp,X_val_tmp,X_test_tmp,y_train_tmp,y_val_tmp,y_test_tmp] = prepare_data( make='',X_train=X_train,X_val=X_val,X_test=X_test,y_train=y_train,y_val=y_val,y_test=y_test)
rg.fit(X_train_tmp, y_train_tmp)
y_val_pred=rg.predict(X_val_tmp)
y_train_pred=rg.predict(X_train_tmp)
y_test_pred=rg.predict(X_test_tmp)


plot_result_1(y_val_tmp, y_val_pred,title = ' - Validation - log test',ylog = ylog)

plot_result_1(y_test_tmp, y_test_pred,title = ' - Validation - log test',ylog = ylog)
# Out:
#  Mean Absolute percentage Error: 0.07156323642851178
#  Mean Absolute percentage Error: 0.07038176745962141
# 0.07038176745962141

# %%
if ylog:
    y_val_tmp = np.exp(y_val_tmp)
    y_val_pred = np.exp(y_val_pred)
X_val['Predicted'] = y_val_pred
X_val['Recorded'] = y_val_tmp
X_val['Error'] = np.abs((np.ravel (y_val_tmp)- np.ravel (y_val_pred))/(np.ravel (y_val_tmp)+ 1))
X_val['absError'] = np.abs((np.ravel (y_val_tmp)- np.ravel (y_val_pred)))

# %%
X_val.sort_values(by=['Error'], ascending=False)[:10]
# Out:
#                 Make        Model  Year  \
# 9959           Dodge    SRT Viper  2014
# 11364        Bugatti  Veyron 16.4  2009
# 6599             BMW       M4 GTS  2016
# 6560           Lexus       LX 470  2005
# 6705         Lincoln    Mark VIII  1998
# 5069   Mercedes-Benz      G-Class  2015
# 6350         Maybach    Landaulet  2011
# 8696           Mazda         RX-7  1994
# 7262           Acura          NSX  2005
# 8300      Land Rover  Range Rover  2014
#
#                                 Engine Fuel Type  Engine HP  Engine Cylinders  \
# 9959                 premium unleaded (required)      640.0              10.0
# 11364                premium unleaded (required)     1001.0              16.0
# 6599                 premium unleaded (required)      493.0               6.0
# 6560                            regular unleaded      235.0               8.0
# 6705                            regular unleaded      290.0               8.0
# 5069                 premium unleaded (required)      382.0               8.0
# 6350                 premium unleaded (required)      620.0              12.0
# 8696                            regular unleaded      255.0               5.0
# 7262                            regular unleaded      252.0               6.0
# 8300   flex-fuel (premium unleaded required/E85)      510.0               8.0
#
#       Transmission Type     Driven_Wheels  Number of Doors  \
# 9959             MANUAL  rear wheel drive              2.0
# 11364  AUTOMATED_MANUAL   all wheel drive              2.0
# 6599   AUTOMATED_MANUAL  rear wheel drive              2.0
# 6560          AUTOMATIC  four wheel drive              4.0
# 6705          AUTOMATIC  rear wheel drive              2.0
# 5069          AUTOMATIC  four wheel drive              4.0
# 6350          AUTOMATIC  rear wheel drive              4.0
# 8696             MANUAL  rear wheel drive              2.0
# 7262          AUTOMATIC  rear wheel drive              2.0
# 8300          AUTOMATIC  four wheel drive              4.0
#
#                              Market Category Vehicle Size Vehicle Style  \
# 9959                 Exotic,High-Performance      Compact         Coupe
# 11364                Exotic,High-Performance      Compact         Coupe
# 6599   Factory Tuner,Luxury,High-Performance      Midsize         Coupe
# 6560                                  Luxury      Midsize       4dr SUV
# 6705                                  Luxury        Large         Coupe
# 5069                                  Luxury      Midsize       4dr SUV
# 6350          Exotic,Luxury,High-Performance        Large   Convertible
# 8696               Factory Tuner,Performance      Compact         Coupe
# 7262          Exotic,Luxury,High-Performance      Compact         Coupe
# 8300       Flex Fuel,Luxury,High-Performance        Large       4dr SUV
#
#        highway MPG  city mpg  Popularity      Predicted   Recorded     Error  \
# 9959            19        12        1851  129527.589727    84885.0  0.525912
# 11364           14         8         820  817960.297524  1705769.0  0.520474
# 6599            23        16        3916   73897.098286   133205.0  0.445234
# 6560            16        12         454   37258.005106    65225.0  0.428771
# 6705            24        15          61    3502.840360     2459.0  0.424325
# 5069            15        12         617   67217.170972   115400.0  0.417525
# 6350            16        10          67  832998.276860  1380000.0  0.396378
# 8696            23        15         586    5045.545379     8147.0  0.380640
# 7262            22        16         204   55289.706181    89000.0  0.378763
# 8300            19        13         258  137261.863781   100100.0  0.371244
#
#             absError
# 9959    44642.589727
# 11364  887808.702476
# 6599    59307.901714
# 6560    27966.994894
# 6705     1043.840360
# 5069    48182.829028
# 6350   547001.723140
# 8696     3101.454621
# 7262    33710.293819
# 8300    37161.863781

# %%
expensive_cars = cars[cars['MSRP']>1000000]

ax=sns.displot(expensive_cars, x= 'MSRP', hue ='Make',common_norm=False, kind="hist", multiple="stack", height=5, aspect=2)

# %%
rg= RandomForestRegressor(n_estimators=200,criterion='squared_error',max_depth=20, n_jobs=-1)


X_train1 = pd.concat([X_train[X_train.Make == 'Bugatti'], X_train[X_train.Make == 'Lamborghini'],X_train[X_train.Make == 'Ferrari']], axis=0)
X_val1 = pd.concat([X_val[X_val.Make == 'Bugatti'], X_val[X_val.Make == 'Lamborghini'],X_val[X_val.Make == 'Ferrari']], axis=0)
X_test1 = pd.concat([X_test[X_test.Make == 'Bugatti'], X_test[X_test.Make == 'Lamborghini'],X_test[X_test.Make == 'Ferrari']], axis=0)

y_train1 = pd.concat([y_train[X_train.Make == 'Bugatti'], y_train[X_train.Make == 'Lamborghini'],y_train[X_train.Make == 'Ferrari']], axis=0)
y_val1 = pd.concat([y_val[X_val.Make == 'Bugatti'], y_val[X_val.Make == 'Lamborghini'],y_val[X_val.Make == 'Ferrari']], axis=0)
y_test1 = pd.concat([y_test[X_test.Make == 'Bugatti'], y_test[X_test.Make == 'Lamborghini'],y_test[X_test.Make == 'Ferrari']], axis=0)

[ X_train_tmp,X_val_tmp,X_test_tmp,y_train_tmp,y_val_tmp,y_test_tmp] = prepare_data( 
    make='',X_train=X_train1,X_val=X_val1,X_test=X_test1,y_train=y_train1,y_val=y_val1,y_test=y_test1)
rg.fit(X_train_tmp, y_train_tmp)
y_val_pred=rg.predict(X_val_tmp)
y_train_pred=rg.predict(X_train_tmp)
y_test_pred=rg.predict(X_test_tmp)


plot_result_1(y_val_tmp, y_val_pred,title = ' - Validation - log test',ylog = ylog)
plot_result_1(y_test_tmp, y_test_pred,title = ' - Validation - log test',ylog = ylog)
# Out:
#  Mean Absolute percentage Error: 0.07876601430702974
#  Mean Absolute percentage Error: 0.1319387147498833
# 0.1319387147498833
